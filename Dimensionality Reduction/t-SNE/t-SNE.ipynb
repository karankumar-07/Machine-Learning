# %%
from sklearn.manifold import TSNE
import pandas as pd

# %%
d0 = pd.read_csv('./train.csv')
l = d0['label']
d = d0.drop("label",axis=1)
d.shape
# Out:
# (42000, 784)

# %%
labels = l
data = d

# %%
from sklearn.preprocessing import StandardScaler
standardized_data = StandardScaler().fit_transform(data)
print(standardized_data.shape)
# Out:
# (42000, 784)

# %%
model = TSNE(n_components=2, random_state=0)
# configuring the parameteres
# the number of components = 2
# default perplexity = 30
# default learning rate = 200
# default Maximum number of iterations for the optimization = 1000

# %%
tsne_data = model.fit_transform(data)

# %%
import numpy as np
tsne_data = np.vstack((tsne_data.T, labels))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-3689ec995bb8> in <module>()
#       1 import numpy as np
# ----> 2 tsne_data = np.vstack((tsne_data.T, labels)).T
#
# /usr/local/Anaconda/lib/python3.6/site-packages/numpy/core/shape_base.py in vstack(tup)
#     232
#     233     """
# --> 234     return _nx.concatenate([atleast_2d(_m) for _m in tup], 0)
#     235
#     236 def hstack(tup):
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly

# %%
tsne_data = tsne_data[:, :3]

# %%
tsne_data = tsne_data.T

# %%
tsne_data.shape
# Out:
# (42000, 3)

# %%
tsne_df = pd.DataFrame(data = tsne_data, columns = ('Dim1', 'Dim2', 'label'))

# %%
import seaborn as sn
import matplotlib.pyplot as plt
sn.FacetGrid(tsne_df, hue="label", size=8).map(plt.scatter, 'Dim1', 'Dim2').add_legend()
plt.show()
